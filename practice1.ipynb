# %%
pip install pybamm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.0/766.0 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 MB 34.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 39.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 42.6 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pybamm

# %%
model=pybamm.lithium_ion.DFN()

# %%
sim=pybamm.Simulation(model)

# %%
sim.solve([0,3600])

# %%
sim.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sim.plot()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pybamm/simulation.py:1060, in Simulation.plot(self, output_variables, **kwargs)
#    1057 if output_variables is None:
#    1058     output_variables = self._output_variables
# -> 1060 self.quick_plot = pybamm.dynamic_plot(
#    1061     self._solution, output_variables=output_variables, **kwargs
#    1062 )
#    1064 return self.quick_plot
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pybamm/plotting/dynamic_plot.py:21, in dynamic_plot(*args, **kwargs)
#      19 kwargs_for_class = {k: v for k, v in kwargs.items() if k != "show_plot"}
#      20 plot = pybamm.QuickPlot(*args, **kwargs_for_class)
# ---> 21 plot.dynamic_plot(kwargs.get("show_plot", True))
#      22 return plot
#
# ...

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
sim.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…
